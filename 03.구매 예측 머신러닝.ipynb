# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 40 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 0s (45.3 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

# %%
import os
os.chdir("/content/drive/MyDrive//금융데이터 공모전")

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("BC card.csv", encoding='cp949')

# %%
sdsf df.loc[['광역시도']['서울특별시']]
# Out:
#   File "<ipython-input-26-2f78466724ca>", line 1
#     sdsf df.loc[['광역시도']['서울특별시']]
#           ^
# SyntaxError: invalid syntax

# %%
grouped = df[['매출건수', '매출금액']].groupby([df['광역시도'],df['시군구'], df['품목중분류명']]).sum()

# %%
seoul2= grouped.loc['서울특별시',:]

# %%
seoul2.to_csv("seoul2.csv")
seoul2= pd.read_csv('seoul2.csv')

# %%
seoul2
# Out:
#       시군구    품목중분류명    매출건수         매출금액
# 0     강남구  DIY자재/용품    1374    144670901
# 1     강남구   e머니/상품권   54757   3734099562
# 2     강남구    o2o서비스  454555  19838725487
# 3     강남구      가공식품   35733   1368787170
# 4     강남구        가방    3194    378461795
# ...   ...       ...     ...          ...
# 1240  중랑구     침구/수예    5386    273871904
# 1241  중랑구        침대     228     38632402
# 1242  중랑구     테이블가구     795     75557372
# 1243  중랑구      패션소품    4931    242162045
# 1244  중랑구        향수     568     30147765
#
# [1245 rows x 4 columns]

# %%
pd.replace()
